# %%
import joblib

model = joblib.load("../models/best_model.pkl")

print(model.feature_name_)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import joblib
#       2
# ----> 3 model = joblib.load("../models/best_model.pkl")
#       4
#       5 print(model.feature_name_)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/best_model.pkl'

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Anansh\Desktop\CODING PROGRAMs\Industrial-AI-Project\FixForesight\notebooks\notebooks

# %%
import os

print(os.listdir())
# Out:
# ['phase2_preprocessing.ipynb']

# %%
print(os.listdir("../models"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(os.listdir("../models"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../models'

# %%
print(os.listdir("models"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(os.listdir("models"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'models'

# %%
import os

print(os.listdir("../.."))
# Out:
# ['.env', '.git', '.gitignore', 'backend', 'code', 'config.ini', 'data', 'docker-compose.yml', 'FixForesight_PersonB_Guide.pdf', 'frontend', 'IMPLEMENTATION_SUMMARY.md', 'infra', 'models', 'notebooks', 'project-build-guide.md', 'QUICKSTART.md', 'README.md', 'reports', 'requirements.txt', 'src', 'TECHNICAL_SPECIFICATIONS.md', 'tests_integration.py', 'training_output.log', 'venv']

# %%
print(os.listdir("../../models"))
# Out:
# ['best_model.pkl', 'diag_target.py', 'inspect_processed.py', 'model_comparison.csv', 'scaler.pkl', 'selected_features.pkl', 'train_models.py', 'verify_data.py']

# %%
import joblib

model = joblib.load("../../models/best_model.pkl")

print(type(model))
# Out:
# <class 'lightgbm.sklearn.LGBMClassifier'>

# %%
print(model.feature_name_)
# Out:
# ['Air_temperature__K_', 'Process_temperature__K_', 'Rotational_speed__rpm_', 'Torque__Nm_', 'Tool_wear__min_', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF', 'temp_difference']
